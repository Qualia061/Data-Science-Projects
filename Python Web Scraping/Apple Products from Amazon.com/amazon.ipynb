# %%
from pandas import DataFrame
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
def scrap_amazon(start_page,end_page):
    url_list = []
    df = pd.DataFrame(columns=['key']) 
    for p in range(start_page,end_page):
        url = 'https://www.amazon.com/s?ie=UTF8&page='+str(p)+'&rh=n%3A2407749011%2Ck%3AApple&page=1'
        url_list.append(url)
        print('Now scraping Page: '+str(p))

        driver = webdriver.Chrome('./chromedriver')
        driver.get(url)

        soup = BeautifulSoup(driver.page_source, 'html.parser')
        lis = soup.find('ul',{'id':'s-results-list-atf'}).find_all('li')
        for li in lis:  #one item
            info_list=[]
            list2 = []
            xpath = li.get('id')
            if xpath:
                xpath = r'//*[@id="'+xpath+r'"]'
                #print(xpath)
                # products = driver.find_element_by_xpath(xpath)
                try:
                    Product_detail = driver.find_element_by_xpath( xpath + r'/div/div/div/div[2]/div[1]/div[1]/a').text
                    #print(Product_detail)
                    list2.append('Product_detail')
                    info_list.append(Product_detail)

                    Manufacturer =   driver.find_element_by_xpath(
                        xpath + r'/div/div/div/div[2]/div[1]/div[2]/span[2]').text
                    #print(Manufacturer)
                    list2.append('Manufacturer')
                    info_list.append(Manufacturer)

                    Offer_Price=''
                    try:
                        Offer_Price=driver.find_element_by_xpath(xpath +r'/div/div/div/div[2]/div[3]/div[1]/div[1]/a').text
                    except:
                        pass
                    try:
                        Offer_Price=driver.find_element_by_xpath(xpath +r'/div/div/div/div[2]/div[2]/div[1]/div[1]/a').text
                        #print(Offer_Price)
                    except:
                        pass
                    if Offer_Price !='':
                        Offer_Price=Offer_Price.replace(' ','',1).replace(' ','.',1)
                        list2.append('Offer_Price')
                        info_list.append(Offer_Price)
                    More_Offer=''
                    try:
                        More_Offer = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[2]/div[1]/div[3]/div[2]/a').text
                        #print(More_Offer)
                    except:
                        pass
                    try:
                        More_Offer = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[3]/div[1]/div[3]/div[2]/a').text
                        #print(More_Offer)
                    except:
                        pass
                    try:
                        More_Offer = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[3]/div[1]/div[2]/div[2]/a').text
                        #print(More_Offer)
                    except:
                        pass
                    try:
                        More_Offer = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[2]/div[1]/div/div/a').text
                        #print(More_Offer)
                    except:
                        pass
                    try:
                        More_Offer = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[2]/div[1]/div[1]/div/a').text
                        #print(More_Offer)
                    except:
                        pass                
                    if More_Offer !='':
                        list2.append('More_Offer')
                        info_list.append(More_Offer)

                    Number_of_Review=''
                    try:
                        Number_of_Review =  driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[2]/div[2]/div/a').text
                    except:
                        pass
                    try:
                        Number_of_Review =  driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[2]/div[2]/div[1]/a').text
                    except:
                        pass
                    try:
                        Number_of_Review =  driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[3]/div[2]/div[1]/a').text
                    except:
                        pass
                    #print(Number_of_Review)
                    if Number_of_Review !='':
                        list2.append('Number_of_Review')
                        info_list.append(Number_of_Review)

                    try:
                        Rating =   li.find('span', {'class': 'a-icon-alt'}).text
                        #print(Rating)
                        list2.append('Rating')
                        info_list.append(Rating)
                    except:
                        pass

                    list_product_info=[]
                    Operating_System=''
                    try:
                        Operating_System = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[2]/div[2]/div[2]/dl/li[1]').text
                        #print(Operating_System)
                    except:
                        pass
                    try:
                        Operating_System = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[3]/div[2]/div[2]/dl/li[1]').text
                        #print(Operating_System)
                    except:
                        pass

                    if Operating_System !='':
                        list_product_info.append(Operating_System)
                        #list2.append('Operating_System')
                        #info_list.append(Operating_System)
                    Display_Size=''
                    try:
                        Display_Size = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[2]/div[2]/div[2]/dl/li[2]').text
                    except:
                        pass
                    try:
                        Display_Size = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[3]/div[2]/div[2]/dl/li[2]').text
                    except:
                        pass

                    if Display_Size !='':
                        list_product_info.append(Display_Size)
                        #list2.append('Display_Size')
                        #info_list.append(Display_Size)
                    Display_Type=''
                    try:
                        Display_Type = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[2]/div[2]/div[2]/dl/li[3]').text
                        #print(Display_Type)
                    except:
                        pass
                    try:
                        Display_Type = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[3]/div[2]/div[2]/dl/li[3]').text
                        #print(Display_Type)
                    except:
                        pass
                    if Display_Type !='':
                        list_product_info.append(Display_Type)
                        #list2.append('Display_Type')
                        #info_list.append(Display_Type)
                    Special=''
                    try:
                        Special = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[2]/div[2]/div[2]/dl/li[4]').text
                        #print(Display_Type)
                    except:
                        pass
                    try:
                        Special = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[3]/div[2]/div[2]/dl/li[4]').text
                        #print(Display_Type)
                    except:
                        pass
                    if Special !='':
                        list_product_info.append(Special)
                    Special_2=''
                    try:
                        Special_2 = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[2]/div[2]/div[2]/dl/li[5]').text
                        #print(Display_Type)
                    except:
                        pass
                    try:
                        Special_2 = driver.find_element_by_xpath(xpath + r'/div/div/div/div[2]/div[3]/div[2]/div[2]/dl/li[5]').text
                        #print(Display_Type)
                    except:
                        pass
                    if Special_2 !='':
                        list_product_info.append(Special_2)
                    for i in list_product_info:
                        if 'Operating System' in i:
                            Operating_System=i.replace('Operating System:','')
                            list2.append('Operating_System')
                            info_list.append(Operating_System)
                        if 'Display Type' in i:
                            Display_Type=i.replace('Display Type:','')
                            list2.append('Display_Type')
                            info_list.append(Display_Type)
                        if 'Display Size' in i:
                            Display_Size=i.replace('Display Size:','')
                            list2.append('Display_Size')
                            info_list.append(Display_Size)
                        if 'Special' in i:
                            Special=i.replace('Special Feature:','')
                            list2.append('Special')
                            info_list.append(Special)

                except:
                    pass
                List = {'key':list2,'value':info_list}
                new = DataFrame(List)
                #print(new)
                if new.empty != True:
                    df=df.merge(new,how='outer',on='key')

            #print('\n\n')
        driver.close()
    df=df.set_index('key')
    new_header = df.iloc[0]
    df = df[1:]
    df.columns = new_header
    return df

# %%
df_page1=scrap_amazon(1,2)
# Out:
# Now scraping Page: 1

# %%
df_page1
# Out:
# Product_detail   Apple iPhone X, Fully Unlocked 5.8", 256 GB - Space Gray  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                               $1,182.93
# More_Offer                            $739.99(98 used & new offers)
# Number_of_Review                                                171
# Rating                                           3.8 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.8 inches
# Display_Type                                                   OLED
# Special                                                         NaN
#
# Product_detail   Apple iPhone XS 5.8" Smartphone Factory Unlocked 256GB 12MP 4G LTE Silver  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                     NaN
# More_Offer                                  $1,270.00(9 new offers)
# Number_of_Review                                                  1
# Rating                                             5 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.8 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone XS 5.8" Smartphone Factory Unlocked 256GB 12MP 4G LTE Gold  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                     NaN
# More_Offer                           $1,145.00(7 used & new offers)
# Number_of_Review                                                  4
# Rating                                           3.5 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.8 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone 8 Plus, GSM Unlocked, 64GB - Space Gray (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $699.77
# More_Offer                                    $554.00(7 new offers)
# Number_of_Review                                                 43
# Rating                                           4.1 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.5 inches
# Display_Type                                                   OLED
# Special                                                         NaN
#
# Product_detail   Apple iPhone X, GSM Unlocked 5.8", 256 GB - Space Gray  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                               $1,180.00
# More_Offer                            $749.99(42 used & new offers)
# Number_of_Review                                                165
# Rating                                           4.1 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.8 inches
# Display_Type                                                   OLED
# Special                                                         NaN
#
# Product_detail   Apple iPhone SE, GSM Unlocked, 16 GB - Space Gray (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $139.99
# More_Offer                                   $134.70(14 new offers)
# Number_of_Review                                                509
# Rating                                           3.9 out of 5 stars
# Operating_System                                                ios
# Display_Size                                               4 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone 6S, GSM Unlocked, 16GB - Rose Gold (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $208.93
# More_Offer                                                      NaN
# Number_of_Review                                                772
# Rating                                           3.9 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             4.7 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone 7 Plus, GSM Unlocked, 128GB - Rose Gold (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $429.99
# More_Offer                                   $429.60(14 new offers)
# Number_of_Review                                                307
# Rating                                           3.7 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.5 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone 7, Fully Unlocked, 32GB - Gold (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $335.55
# More_Offer                                   $298.99(10 new offers)
# Number_of_Review                                                194
# Rating                                           3.4 out of 5 stars
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone 7 Plus, GSM Unlocked, 32GB - Black (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $399.99
# More_Offer                                   $366.99(17 new offers)
# Number_of_Review                                                444
# Rating                                           3.9 out of 5 stars
# Operating_System                                                iOS
# Display_Size                                             5.5 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail                        ...                        \
# key                                   ...
# Manufacturer                          ...
# Offer_Price                           ...
# More_Offer                            ...
# Number_of_Review                      ...
# Rating                                ...
# Operating_System                      ...
# Display_Size                          ...
# Display_Type                          ...
# Special                               ...
#
# Product_detail   Apple iPhone 6S, GSM Unlocked, 16GB - Space Gray (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $219.99
# More_Offer                                                      NaN
# Number_of_Review                                                449
# Rating                                           3.8 out of 5 stars
# Operating_System                                             IOS 10
# Display_Size                                             4.7 inches
# Display_Type                                                    LCD
# Special                                                         NaN
#
# Product_detail   Refurbished Apple Watch Series 2, 42mm Space Black Stainless Steel Case with Black Sport Band  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $229.00
# More_Offer                                    $219.95(2 new offers)
# Number_of_Review                                                 47
# Rating                                           3.5 out of 5 stars
# Operating_System                                                NaN
# Display_Size                                             1.5 inches
# Display_Type                                                   OLED
# Special                                                  waterproof
#
# Product_detail   Apple iPhone XR, Fully Unlocked 6.1", 64 GB - White  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $915.00
# More_Offer                                    $900.00(5 new offers)
# Number_of_Review                                                NaN
# Rating                                                          NaN
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone 8, Fully Unlocked, 64GB - Gold (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $539.99
# More_Offer                                    $497.20(6 new offers)
# Number_of_Review                                                 68
# Rating                                           3.9 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             4.7 inches
# Display_Type                                                   OLED
# Special                                                         NaN
#
# Product_detail   Apple iPhone 7 Plus, GSM Unlocked, 128GB - Silver (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $438.99
# More_Offer                                   $428.95(12 new offers)
# Number_of_Review                                                 64
# Rating                                           3.8 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.5 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone 4S, GSM Unlocked, 16GB - Black (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                  $64.99
# More_Offer                                                      NaN
# Number_of_Review                                                335
# Rating                                           3.2 out of 5 stars
# Operating_System                                                iOS
# Display_Size                                             3.5 inches
# Display_Type                                                    NaN
# Special                                                 touchscreen
#
# Product_detail   Apple iPhone 8, GSM Unlocked, 64GB - Gold (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $469.99
# More_Offer                                    $452.99(8 new offers)
# Number_of_Review                                                 48
# Rating                                           3.9 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             4.7 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone 6, GSM Unlocked, 64GB - Space Gray (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $199.95
# More_Offer                                                      NaN
# Number_of_Review                                                397
# Rating                                           2.9 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             4.5 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone 6, GSM Unlocked, 16GB - Space Gray (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $167.90
# More_Offer                                                      NaN
# Number_of_Review                                              2,285
# Rating                                             3 out of 5 stars
# Operating_System                                              IOS 8
# Display_Size                                             4.7 inches
# Display_Type                                                    LCD
# Special                                          fingerprint-sensor
#
# Product_detail   Apple iPhone 7 32 GB Unlocked, Gold US Version
# key
# Manufacturer                                              Apple
# Offer_Price                                             $509.92
# More_Offer                        $249.94(41 used & new offers)
# Number_of_Review                                             31
# Rating                                         4 out of 5 stars
# Operating_System                                         iOS 11
# Display_Size                                         4.7 inches
# Display_Type                                                NaN
# Special                                                     NaN
#
# [9 rows x 24 columns]

# %%
df_page2to4=scrap_amazon(2,4)
# Out:
# Now scraping Page: 2
# Now scraping Page: 3

# %%
df_page2to4
# Out:
# Product_detail   Apple iPhone SE 32GB Factory Unlocked Smartphone for GSM Carriers, Space Gray  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $299.99
# More_Offer                            $119.97(33 used & new offers)
# Number_of_Review                                              1,112
# Rating                                             4 out of 5 stars
# Operating_System                                                iOS
# Display_Size                                               4 inches
# Special                                                         NaN
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone 4S, GSM Unlocked, 16GB - White (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                  $59.99
# More_Offer                                                      NaN
# Number_of_Review                                                387
# Rating                                           3.1 out of 5 stars
# Operating_System                                                iOS
# Display_Size                                             3.5 inches
# Special                                                 touchscreen
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone XS Max, Fully Unlocked 6.5", 256 GB - Space Gray  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                     NaN
# More_Offer                          $1,185.00(19 used & new offers)
# Number_of_Review                                                 23
# Rating                                           4.1 out of 5 stars
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Special                                                         NaN
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone 7 Plus, GSM Unlocked, 128GB - Red (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $484.99
# More_Offer                                                      NaN
# Number_of_Review                                                 14
# Rating                                           4.2 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.5 inches
# Special                                                  waterproof
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone 7, GSM Unlocked, 32GB - Black (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $302.53
# More_Offer                                                      NaN
# Number_of_Review                                                117
# Rating                                           3.5 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             4.7 inches
# Special                                                         NaN
# Display_Type                                                    LCD
#
# Product_detail   Apple iPhone 6S, Fully Unlocked, 64GB - (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $269.99
# More_Offer                                   $254.00(10 new offers)
# Number_of_Review                                                342
# Rating                                           3.6 out of 5 stars
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Special                                                         NaN
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone 6S Plus, GSM Unlocked, 64GB - Space Gray (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $359.99
# More_Offer                                    $295.99(6 new offers)
# Number_of_Review                                                682
# Rating                                             4 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             4.7 inches
# Special                                      touchscreendual-camera
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone 6S, GSM Unlocked, 64GB - Gold (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $249.00
# More_Offer                                                      NaN
# Number_of_Review                                                205
# Rating                                           3.6 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             4.7 inches
# Special                                                         NaN
# Display_Type                                                    LCD
#
# Product_detail   Apple iPhone 6, Fully Unlocked, 16GB - Space Gray (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $180.99
# More_Offer                                                      NaN
# Number_of_Review                                                  3
# Rating                                           3.4 out of 5 stars
# Operating_System                                                iOS
# Display_Size                                             4.7 inches
# Special                                             FaceTime Camera
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone SE, GSM Unlocked, 32GB - Space Gray (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $150.98
# More_Offer                                    $147.99(9 new offers)
# Number_of_Review                                                 64
# Rating                                           3.8 out of 5 stars
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Special                                                         NaN
# Display_Type                                                    NaN
#
# Product_detail                              ...                              \
# key                                         ...
# Manufacturer                                ...
# Offer_Price                                 ...
# More_Offer                                  ...
# Number_of_Review                            ...
# Rating                                      ...
# Operating_System                            ...
# Display_Size                                ...
# Special                                     ...
# Display_Type                                ...
#
# Product_detail   Apple iPhone 6, Fully Unlocked, 16GB - Silver (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $174.00
# More_Offer                                                      NaN
# Number_of_Review                                                 67
# Rating                                           3.4 out of 5 stars
# Operating_System                                              ios 8
# Display_Size                                             4.7 inches
# Special                                                 lightweight
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone 6S Plus, GSM Unlocked, 64 GB - Gold (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $326.48
# More_Offer                                    $322.00(8 new offers)
# Number_of_Review                                                124
# Rating                                           3.7 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             4.7 inches
# Special                                                         NaN
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone 6S, GSM Unlocked, 64GB - Silver (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $255.00
# More_Offer                                    $249.32(8 new offers)
# Number_of_Review                                                183
# Rating                                           3.8 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             4.7 inches
# Special                                                         NaN
# Display_Type                                                    LCD
#
# Product_detail   Apple iPhone 5S, GSM Unlocked, 16GB - Space Gray (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $104.99
# More_Offer                                                      NaN
# Number_of_Review                                                 18
# Rating                                           3.6 out of 5 stars
# Operating_System                                            iOS 7.0
# Display_Size                                             4.0 inches
# Special                                                 lightweight
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone 8 Plus, GSM Unlocked, 64GB - Gold (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $599.98
# More_Offer                                                      NaN
# Number_of_Review                                                 31
# Rating                                           3.8 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.5 inches
# Special                                                         NaN
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone 6, GSM Unlocked, 16GB - Silver (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $179.00
# More_Offer                                                      NaN
# Number_of_Review                                                120
# Rating                                           3.2 out of 5 stars
# Operating_System                                                iOS
# Display_Size                                             4.7 inches
# Special                                                  Microphone
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone 6S Plus, GSM Unlocked, 64GB, Rose Gold (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $330.83
# More_Offer                                   $314.99(10 new offers)
# Number_of_Review                                                 28
# Rating                                           3.7 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.5 inches
# Special                                                         NaN
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone 7 Plus, AT&T, 128GB - Black (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $479.99
# More_Offer                                    $409.99(5 new offers)
# Number_of_Review                                                  4
# Rating                                             5 out of 5 stars
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Special                                                         NaN
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone SE 16GB Unlocked for GSM Carriers (AT&T, T-Mobile) - Rose Gold  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $229.99
# More_Offer                             $129.95(6 used & new offers)
# Number_of_Review                                                  7
# Rating                                             5 out of 5 stars
# Operating_System                                                iOS
# Display_Size                                             4.0 inches
# Special                                                         NaN
# Display_Type                                                    NaN
#
# Product_detail   Apple iPhone 6S, Fully Unlocked, 16GB - Gold (Refurbished)
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $219.00
# More_Offer                                                      NaN
# Number_of_Review                                                 48
# Rating                                           4.1 out of 5 stars
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Special                                                         NaN
# Display_Type                                                    NaN
#
# [9 rows x 48 columns]

# %%
df_page1to59=scrap_amazon(1,59)
# Out:
# Now scraping Page: 1
# Now scraping Page: 2
# Now scraping Page: 3
# Now scraping Page: 4
# Now scraping Page: 5
# Now scraping Page: 6
# Now scraping Page: 7
# Now scraping Page: 8
# Now scraping Page: 9
# Now scraping Page: 10
# Now scraping Page: 11
# Now scraping Page: 12
# Now scraping Page: 13
# Now scraping Page: 14
# Now scraping Page: 15
# Now scraping Page: 16
# Now scraping Page: 17
# Now scraping Page: 18
# Now scraping Page: 19
# Now scraping Page: 20
# Now scraping Page: 21
# Now scraping Page: 22
# Now scraping Page: 23
# Now scraping Page: 24
# Now scraping Page: 25
# Now scraping Page: 26
# Now scraping Page: 27
# Now scraping Page: 28
# Now scraping Page: 29
# Now scraping Page: 30
# Now scraping Page: 31
# Now scraping Page: 32
# Now scraping Page: 33
# Now scraping Page: 34
# Now scraping Page: 35
# Now scraping Page: 36
# Now scraping Page: 37
# Now scraping Page: 38
# Now scraping Page: 39
# Now scraping Page: 40
# Now scraping Page: 41
# Now scraping Page: 42
# Now scraping Page: 43
# Now scraping Page: 44
# Now scraping Page: 45
# Now scraping Page: 46
# Now scraping Page: 47
# Now scraping Page: 48
# Now scraping Page: 49
# Now scraping Page: 50
# Now scraping Page: 51
# Now scraping Page: 52
# Now scraping Page: 53
# Now scraping Page: 54
# Now scraping Page: 55
# Now scraping Page: 56
# Now scraping Page: 57
# Now scraping Page: 58

# %%
df_page1to59
# Out:
# Product_detail   Apple iPhone X, Fully Unlocked 5.8", 256 GB - Space Gray  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                               $1,167.96
# More_Offer                            $739.99(95 used & new offers)
# Number_of_Review                                                171
# Rating                                           3.8 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.8 inches
# Display_Type                                                   OLED
# Special                                                         NaN
#
# Product_detail   Apple iPhone XS 5.8" Smartphone Factory Unlocked 256GB 12MP 4G LTE Silver  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                     NaN
# More_Offer                                  $1,270.00(9 new offers)
# Number_of_Review                                                  1
# Rating                                             5 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.8 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone 7 Plus, GSM Unlocked, 32GB - Rose Gold (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $409.00
# More_Offer                                   $403.99(11 new offers)
# Number_of_Review                                                445
# Rating                                           3.9 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.5 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone XS 5.8" Smartphone Factory Unlocked 256GB 12MP 4G LTE Gold  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                     NaN
# More_Offer                           $1,145.00(8 used & new offers)
# Number_of_Review                                                  4
# Rating                                           3.5 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.8 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone X, GSM Unlocked 5.8", 256 GB - Space Gray  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                               $1,200.00
# More_Offer                            $749.99(34 used & new offers)
# Number_of_Review                                                165
# Rating                                           4.1 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.8 inches
# Display_Type                                                   OLED
# Special                                                         NaN
#
# Product_detail   Apple iPhone 8 Plus, GSM Unlocked, 64GB - Space Gray (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                     NaN
# More_Offer                                    $586.58(8 new offers)
# Number_of_Review                                                 43
# Rating                                           4.1 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.5 inches
# Display_Type                                                   OLED
# Special                                                         NaN
#
# Product_detail   Apple iPhone SE, GSM Unlocked, 16 GB - Space Gray (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $139.99
# More_Offer                                   $133.95(14 new offers)
# Number_of_Review                                                509
# Rating                                           3.9 out of 5 stars
# Operating_System                                                ios
# Display_Size                                               4 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone 6S Plus, GSM Unlocked, 64GB - Space Gray (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $359.99
# More_Offer                                    $301.76(6 new offers)
# Number_of_Review                                                683
# Rating                                             4 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             4.7 inches
# Display_Type                                                    NaN
# Special                                      touchscreendual-camera
#
# Product_detail   Apple iPhone 7 Plus, GSM Unlocked, 128GB - Rose Gold (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $429.99
# More_Offer                                   $419.99(16 new offers)
# Number_of_Review                                                307
# Rating                                           3.7 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             5.5 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Apple iPhone 7 128GB (GSM Unlocked) - Rose Gold (Refurbished)  \
# key
# Manufacturer                                                  Apple
# Offer_Price                                                 $349.99
# More_Offer                                   $323.66(24 new offers)
# Number_of_Review                                                851
# Rating                                           3.5 out of 5 stars
# Operating_System                                                ios
# Display_Size                                             4.7 inches
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail                                                                       ...                                                                      \
# key                                                                                  ...
# Manufacturer                                                                         ...
# Offer_Price                                                                          ...
# More_Offer                                                                           ...
# Number_of_Review                                                                     ...
# Rating                                                                               ...
# Operating_System                                                                     ...
# Display_Size                                                                         ...
# Display_Type                                                                         ...
# Special                                                                              ...
#
# Product_detail   Scheam iPhone 7 iPhone 8 Case, Premium PU Leather Wallet Pouch Flip Cover Case Anti-Scratch Defender CoverWomen for iPhone 7 iPhone 8 (Black)  \
# key
# Manufacturer                                                 Scheam
# Offer_Price                                                     NaN
# More_Offer                                      $10.99(1 new offer)
# Number_of_Review                                                NaN
# Rating                                                          NaN
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Scheam iPhone 7 iPhone 8 Case, Premium PU Leather Wallet Pouch Flip Cover Case Anti-Scratch Defender CoverWomen for iPhone 7 iPhone 8 (Coffee)  \
# key
# Manufacturer                                                 Scheam
# Offer_Price                                                     NaN
# More_Offer                                      $10.99(1 new offer)
# Number_of_Review                                                NaN
# Rating                                                          NaN
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   iPhone 6 iPhone 6s 4.7 inch Case,Premium Protects Premium PU Leather Wallet Case Protects with Kickstand and Credit Card Slot Cash Holder Flip Cover for iPhone 6 iPhone 6s 4.7 inch Red  \
# key
# Manufacturer                                                 Scheam
# Offer_Price                                                     NaN
# More_Offer                                       $8.99(1 new offer)
# Number_of_Review                                                NaN
# Rating                                                          NaN
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   iPhone 9 - Excellent PU Wallet Style Flip Cover Case for iPhone 9 ONLY (iPhone 9 Cover Pink)  \
# key
# Manufacturer                                                 Scheam
# Offer_Price                                                     NaN
# More_Offer                                       $8.99(1 new offer)
# Number_of_Review                                                NaN
# Rating                                                          NaN
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   iPhone 9 - Excellent PU Wallet Style Flip Cover Case for iPhone 9 ONLY (iPhone 9 Cover Red)  \
# key
# Manufacturer                                                 Scheam
# Offer_Price                                                     NaN
# More_Offer                                       $8.99(1 new offer)
# Number_of_Review                                                NaN
# Rating                                                          NaN
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Scheam iPhone 9 Case, iPhone 9 Wallet Case,PU, Premium Slim Leather Wallet Back Case with Credit Card ID Holder Protective Cover for iPhone 9,Blue  \
# key
# Manufacturer                                                 Scheam
# Offer_Price                                                     NaN
# More_Offer                                       $8.99(1 new offer)
# Number_of_Review                                                NaN
# Rating                                                          NaN
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Scheam iPhone X Case Luxury PU Leather Wallet Flip Protective PU Leather Case Cover with Card Slots and Stand for iPhone X Coffee  \
# key
# Manufacturer                                                 Scheam
# Offer_Price                                                     NaN
# More_Offer                                       $8.99(1 new offer)
# Number_of_Review                                                NaN
# Rating                                                          NaN
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Scheam iPhone 7 iPhone 8 Wallet Case, iPhone 7 iPhone 8 Case, Premium Leather Zipper Wallet Multifunctional Backcase Removable Card Slot Pocket Pouch Flip Protective Cover for iPhone 7 iPhone 8 -  \
# key
# Manufacturer                                                 Scheam
# Offer_Price                                                     NaN
# More_Offer                                       $8.99(1 new offer)
# Number_of_Review                                                NaN
# Rating                                                          NaN
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Scheam Flip Wallet Case for iPhone 7 Plus iPhone 8 Plus Folio Shock Protection with Card Slots Lightweight Grip and Adjustable Stand Black  \
# key
# Manufacturer                                                 Scheam
# Offer_Price                                                     NaN
# More_Offer                                       $8.99(1 new offer)
# Number_of_Review                                                NaN
# Rating                                                          NaN
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Display_Type                                                    NaN
# Special                                                         NaN
#
# Product_detail   Scheam Flip Wallet Case for iPhone 7 Plus iPhone 8 Plus Folio Shock Protection with Card Slots Lightweight Grip and Adjustable Stand Coffee
# key
# Manufacturer                                                 Scheam
# Offer_Price                                                     NaN
# More_Offer                                       $8.99(1 new offer)
# Number_of_Review                                                NaN
# Rating                                                          NaN
# Operating_System                                                NaN
# Display_Size                                                    NaN
# Display_Type                                                    NaN
# Special                                                         NaN
#
# [9 rows x 1392 columns]
